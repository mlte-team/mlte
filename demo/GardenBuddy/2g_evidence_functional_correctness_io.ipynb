# %% [markdown]
# ## 2g. Evidence - Functional Correctness - I/O Specification QAS Measurements
#
# Measure proper input specification.

# %%
{
    "tags": [],
    "quality_attribute": "",
    "description": "",
    "inputs": "",
    "output": "",
}

# %% [markdown]
# ### Initialize MLTE Context
#
# MLTE contains a global context that manages the currently active _session_. Initializing the context tells MLTE how to store all of the artifacts that it produces. This import will also set up global constants related to folders and model to use.

# %%
# Sets up context for the model being used, sets up constants related to folders and model data to be used.
from session import *
# Out:
# Creating initial custom lists at URI: local:///Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/../store
# Loaded 7 qa_categories for initial list
# Loaded 30 quality_attributes for initial list
# Creating sample catalog at URI: StoreType.LOCAL_FILESYSTEM:local:///Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/../store
# Loading sample catalog entries.
# Loaded 9 entries for sample catalog.

# %% [markdown]
# ### Set up scenario test case

# %%
from mlte.negotiation.artifact import NegotiationCard

card = NegotiationCard.load()
qa = 6
print(card.quality_scenarios[qa].identifier)
print(card.quality_scenarios[qa].quality)
print(
    card.quality_scenarios[qa].stimulus,
    "from ",
    card.quality_scenarios[qa].source,
    " during ",
    card.quality_scenarios[qa].environment,
    ". ",
    card.quality_scenarios[qa].response,
    card.quality_scenarios[qa].measure,
)
# Out:
# card.default-qas_007
# Functional Correctness
# The model receives a picture taken at the garden from  the Garden Buddy application  during  normal operations .  Model correctly processes inputs and produces outputs according to established input and output specifications without exceptions

# %% [markdown]
# **A Specific test case generated from the scenario:**
#
# **Data and Data Source:**	Test dataset must conform to input specification.
#
# **Measurement and Condition:**	During test execution all data in the test dataset produces an output that conforms to the output specification.
#
# **Context:**	Normal Operation

# %% [markdown]
# ### Helper Functions
#
# Prepare all functions and data for the measurements.

# %%
# Load model module
from utils import model_predict
from utils import garden


def run_and_get_log() -> str:
    """Runs the model and gets the log."""
    model_predict.run_model(SAMPLE_DATASET_DIR, MODEL_FILE_PATH)

    return model_predict.load_log()

# %% [markdown]
# ### Measurements
#
# Finally, we execute the measurements and store the results.

# %%
from mlte.measurement.external_measurement import ExternalMeasurement
from mlte.evidence.types.string import String

# Check input format is okay.
measurement = ExternalMeasurement(
    "input format validation success", String, run_and_get_log
)
result = measurement.evaluate()
# print(result)
result.save(force=True)

# Check output format is okay.
measurement = ExternalMeasurement(
    "output format validation success", String, run_and_get_log
)
result = measurement.evaluate()
# print(result)
result.save(force=True)
# Out:
# Deleting log
# TensorFlow version: 2.18.0
# Found 1 files.
# Size of model file (/Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/model/oxford_flower_model.keras): 206705544 bytes
# Memory used for the entire model loading process: 543145984 bytes.
# Running inference on 1 samples...
# (1, 224, 224, 3)
# Model - Input Validation Pass - RGB image loaded
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 573ms/step
# Model - Output Validation Pass - (1, 102) - validated
# Model - file: /Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/data/sample predicted to be lotus (class [55]) with confidence [0.02620832]
#
# --- STATISTICS ---
# Average elapsed time per inference: 0.61206 seconds
# Average memory used per inference: 33406976.00000 bytes.
# Deleting log
# TensorFlow version: 2.18.0
# Found 1 files.
# Size of model file (/Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/model/oxford_flower_model.keras): 206705544 bytes
# Memory used for the entire model loading process: 209666048 bytes.
# Running inference on 1 samples...
# (1, 224, 224, 3)
# Model - Input Validation Pass - RGB image loaded
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 544ms/step
# Model - Output Validation Pass - (1, 102) - validated
# Model - file: /Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/data/sample predicted to be lotus (class [55]) with confidence [0.02620832]
#
# --- STATISTICS ---
# Average elapsed time per inference: 0.55854 seconds
# Average memory used per inference: 30752768.00000 bytes.
# ArtifactModel(header=ArtifactHeaderModel(identifier='evidence.output format validation success', type='evidence', timestamp=1762182245, creator=None, level='version'), body=EvidenceModel(artifact_type=<ArtifactType.EVIDENCE: 'evidence'>, metadata=EvidenceMetadata(test_case_id='output format validation success', measurement=MeasurementMetadata(measurement_class='mlte.measurement.external_measurement.ExternalMeasurement', output_class='mlte.evidence.types.string.String', additional_data={'function': '__main__.run_and_get_log'})), evidence_class='mlte.evidence.types.string.String', value=StringValueModel(evidence_type=<EvidenceType.STRING: 'string'>, string='2025-11-03 10:04:04,593 TensorFlow version: 2.18.0\n2025-11-03 10:04:05,006 Loaded model from disk!\n2025-11-03 10:04:05,006 Size of model file (/Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/model/oxford_flower_model.keras): 206705544 bytes\n2025-11-03 10:04:05,006 Memory used for the entire model loading process: 209666048 bytes.\n2025-11-03 10:04:05,007 Running inference on 1 samples...\n2025-11-03 10:04:05,014 Model - Input Validation Pass - RGB image loaded\n2025-11-03 10:04:05,573 Model - Output Validation Pass - (1, 102) - validated\n2025-11-03 10:04:05,574 Model - file: /Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/data/sample predicted to be lotus (class [55]) with confidence [0.02620832]\n2025-11-03 10:04:05,575 \n--- STATISTICS ---\n2025-11-03 10:04:05,575 Average elapsed time per inference: 0.55854 seconds\n2025-11-03 10:04:05,576 Average memory used per inference: 30752768.00000 bytes.\n')))
