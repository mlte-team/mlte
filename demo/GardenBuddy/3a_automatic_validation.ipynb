# %% [markdown]
# ## 3a. Automatic Validation
#
# The final phase of SDMT involves aggregating evidence, validating the metrics reflected by the evidence we collected, and displaying this information in a report. In this first step, we will do the automatic validation of the test cases against the `Evidence` we have collected.

# %% [markdown]
# ### Initialize MLTE Context
#
# MLTE contains a global context that manages the currently active session. Initializing the context tells MLTE how to store all of the artifacts that it produces. This import will also set up global constants related to folders and model to use.

# %%
# Sets up context for the model being used, sets up constants related to folders and model data to be used.
from session import *
# Out:
# Creating initial custom lists at URI: local:///Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/../store
# Loaded 7 qa_categories for initial list
# Loaded 30 quality_attributes for initial list
# Creating sample catalog at URI: StoreType.LOCAL_FILESYSTEM:local:///Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/../store
# Loading sample catalog entries.
# Loaded 9 entries for sample catalog.

# %% [markdown]
# ### Automatic Validation
#
# Now run the automatic validation for all test cases, given the collected `Evidence` in the store.

# %%
from mlte.validation.test_suite_validator import TestSuiteValidator

# Load validator for default TestSuite id
test_suite_validator = TestSuiteValidator()

# Load all Evidence and validate TestCases
test_results = test_suite_validator.load_and_validate()

# We want to see the validation results in the Notebook, regardless of them being saved.
test_results.print_results()

# TestResults also supports persistence
test_results.save(force=True)
# Out:
#  > Test Case: accuracy across gardens, result: Success, details: All accuracies are equal to or over threshold 0.9 - values: ["[0.936, 0.945, 0.946]"]
#  > Test Case: ranksums blur2x8, result: Success, details: P-Value is greater or equal to 0.016666666666666666 - values: ["[0.07946178703316073, 0.9366653249981838]"]
#  > Test Case: ranksums blur5x8, result: Success, details: P-Value is greater or equal to 0.016666666666666666 - values: ["[0.4032389192727559, 0.6867724711187835]"]
#  > Test Case: ranksums blur0x8, result: Failure, details: P-Value is less than threshold 0.016666666666666666 - values: ["[2.908064206049404, 0.003636736621916332]"]
#  > Test Case: effect of blur across families, result: Success, details: All p-values are equal to or over threshold 0.0003546099290780142 - values: ["{'array': [{'evidence.ranksums Order Apiales-Apiales blurdelta_2x8': [0.0, 1.0]}, {'evidence.ranksums Order Apiales-Alismatales blurdelta_2x8': [0.0, 1.0]}, {'evidence.ranksums Order Apiales-Asterales blurdelta_2x8': [-0.1091089451179962, 0.9131160800723744]}, {'evidence.ranksums Order Apiales-Erica..."]
#  > Test Case: ranksums channel loss R, result: Success, details: P-Value is greater or equal to 0.05 - values: ["[0.8052918417241214, 0.4206512885130542]"]
#  > Test Case: ranksums channel loss G, result: Success, details: P-Value is greater or equal to 0.05 - values: ["[0.6356942962652858, 0.5249756947411197]"]
#  > Test Case: ranksums channel loss B, result: Success, details: P-Value is greater or equal to 0.05 - values: ["[0.7673399434396266, 0.44287942555285786]"]
#  > Test Case: model size, result: Failure, details: Real magnitude exceeds threshold 150 megabyte - values: ["206705557.0 byte"]
#  > Test Case: predicting memory, result: Success, details: Average utilization below threshold 512.0 megabyte - values: ["Average: 462920 kilobyte\nMinimum: 736 kilobyte\nMaximum: 1059504 kilobyte"]
#  > Test Case: predicting cpu, result: Success, details: Maximum utilization below threshold 30.0 percent - values: ["Average: 1.6158333333333335 percent\nMinimum: 0.0 percent\nMaximum: 5.032 percent"]
#  > Test Case: image attributions, result: Info, details: Inspect the image.
#  > Test Case: overall model accuracy, result: Success, details: Real magnitude is greater than threshold 0.9 - values: ["0.947265625"]
#  > Test Case: input format validation success, result: Success, details: Substring 'Model - Input Validation Pass' is contained in the string value. - values: ["2025-11-03 10:04:03,166 TensorFlow version: 2.18.0\n2025-11-03 10:04:03,959 Loaded model from disk!\n2025-11-03 10:04:03,959 Size of model file (/Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/model/oxford_flower_model.keras): 206705544 bytes\n2025-11-03..."]
#  > Test Case: output format validation success, result: Success, details: Substring 'Model - Output Validation Pass' is contained in the string value. - values: ["2025-11-03 10:04:04,593 TensorFlow version: 2.18.0\n2025-11-03 10:04:05,006 Loaded model from disk!\n2025-11-03 10:04:05,006 Size of model file (/Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/model/oxford_flower_model.keras): 206705544 bytes\n2025-11-03..."]
#  > Test Case: input format validation error, result: Failure, details: Substring 'Model - Input Validation Error' is not contained in the string value. - values: ["2025-11-03 10:12:33,135 TensorFlow version: 2.18.0\n2025-11-03 10:12:33,917 Loaded model from disk!\n2025-11-03 10:12:33,917 Size of model file (/Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/model/oxford_flower_model.keras): 206705544 bytes\n2025-11-03..."]
#  > Test Case: detect ood inputs, result: Success, details: Substring 'Model - Input OOD Error' is contained in the string value. - values: ["2025-11-03 10:17:53,270 TensorFlow version: 2.18.0\n2025-11-03 10:17:53,953 Loaded model from disk!\n2025-11-03 10:17:53,953 Size of model file (/Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/model/oxford_flower_model.keras): 206705544 bytes\n2025-11-03..."]
#  > Test Case: monitor output confidence shift, result: Failure, details: Substring 'Model - Output Confidence Error' is not contained in the string value. - values: ["2025-11-03 10:17:58,005 TensorFlow version: 2.18.0\n2025-11-03 10:17:58,435 Loaded model from disk!\n2025-11-03 10:17:58,436 Size of model file (/Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/model/oxford_flower_model.keras): 206705544 bytes\n2025-11-03..."]
#  > Test Case: predicting cpu time, result: Success, details: Real magnitude is less than threshold 2.0 second - values: ["1.0287079811096191 second"]
#  > Test Case: repeated results sampling, result: Success, details: P-Value is greater or equal to 0.05 - values: ["[38.903978816768415, 0.8487546281441082]"]
#  > Test Case: repeated training on training samples, result: Success, details: P-Value is greater or equal to 0.05 - values: ["[1.3575418994429564, 0.9980720828075595]"]
#  > Test Case: running in new domain, result: Failure, details: One or more p-values are below threshold 0.05 - values: ["{'array': [{'evidence.label 0': [35.98058233033483, 7.269476178488252e-06]}, {'evidence.label 1': [1.2823981355178078, 0.2715430886274718]}, {'evidence.label 2': [4.059687454037485, 0.05829167989491706]}, {'evidence.label 3': [0.000382861952999998, 0.9845827951232068]}, {'evidence.label 4': [26.6332..."]
#  > Test Case: test results from dev and op env, result: Info, details: Inspect the alignment of results for no more than 0.25% difference.
#  > Test Case: understanding design choices, result: Info, details: Inspect project code and documentation.
#  > Test Case: keep ML component up to date, result: Info, details: Validate work time less than 8hrs.
#  > Test Case: update data pipelines, result: Info, details: Validate work time less than 4hrs.
#  > Test Case: update ML training algorithm, result: Info, details: Validate train time less than 16hrs.
#  > Test Case: retrain ML model, result: Info, details: Model takes less than 1 hr to retrain.
#  > Test Case: reuse ML component, result: Info, details: Validate work time less than 4hrs.
# ArtifactModel(header=ArtifactHeaderModel(identifier='results.default', type='results', timestamp=1762184887, creator=None, level='version'), body=TestResultsModel(artifact_type=<ArtifactType.TEST_RESULTS: 'results'>, test_suite_id='suite.default', test_suite=TestSuiteModel(artifact_type=<ArtifactType.TEST_SUITE: 'suite'>, test_cases=[TestCaseModel(identifier='accuracy across gardens', goal='Check if model performs well accross different populations', qas_list=['card.default-qas_001'], measurement=None, validator=ValidatorModel(bool_exp='...', bool_exp_str='lambda value: (sum(((g >= threshold) for g in value.array)) == len(value.array))', thresholds=[], success='All accuracies are equal to or over threshold 0.9', failure='One or more accuracies are below threshold 0.9', info=None, input_types=['mlte.evidence.types.array.Array'], creator_entity='validators', creator_function='all_accuracies_more_or_equal_than', creator_args=['0.9'])), TestCaseModel(identifier='ranksums blur2x8', goal='Check blur and noise for 2x8 case', qas_list=['card.default-qas_002'], measurement=None, validator=ValidatorModel(bool_exp='...', bool_exp_str='lambda value: (value.array[P_VALUE_POS] >= threshold)', thresholds=[], success='P-Value is greater or equal to 0.016666666666666666', failure='P-Value is less than threshold 0.016666666666666666', info=None, input_types=['mlte.evidence.types.array.Array'], creator_entity='validators', creator_function='p_value_greater_or_equal_to', creator_args=['0.016666666666666666'])), TestCaseModel(identifier='ranksums blur5x8', goal='Check blur and noise for 5x8 case', qas_list=['card.default-qas_002'], measurement=None, validator=ValidatorModel(bool_exp='...', bool_exp_str='lambda value: (value.array[P_VALUE_POS] >= threshold)', thresholds=[], success='P-Value is greater or equal to 0.016666666666666666', failure='P-Value is less than threshold 0.016666666666666666', info=None, input_types=['mlte.evidence.types.array.Array'], creator_entity='validators', creator_function='p_value_greater_or_equal_to', creator_args=['0.016666666666666666'])), TestCaseModel(identifier='ranksums blur0x8', goal='Check blur and noise for 0x8 case', qas_list=['card.default-qas_002'], measurement=None, validator=ValidatorModel(bool_exp='...', bool_exp_str='lambda value: (value.array[P_VALUE_POS] >= threshold)', thresholds=[], success='P-Value is greater or equal to 0.016666666666666666', failure='P-Value is less than threshold 0.016666666666666666', info=None, input_types=['mlte.evidence.types.array.Array'], creator_entity='validators', creator_function='p_value_greater_or_equal_to', creator_args=['0.016666666666666666'])), TestCaseModel(identifier='effect of blur across families', goal='Check consistency in families', qas_list=['card.default-qas_002'], measurement=None, validator=ValidatorModel(bool_exp='...', bool_exp_str='lambda value: (len(value.get_low_p_values(threshold)) == 0)', thresholds=['0.0003546099290780142'], success='All p-values are equal to or over threshold 0.0003546099290780142', failure='One or more p-values are below threshold 0.0003546099290780142', info=None, input_types=['evidence.multiple_ranksums.MultipleRanksums'], creator_entity='evidence.multiple_ranksums.MultipleRanksums', creator_function='all_p_values_greater_or_equal_than', creator_args=['0.0003546099290780142'])), TestCaseModel(identifier='ranksums channel loss R', goal='Check consistency between channel loss', qas_list=['card.default-qas_003'], measurement=None, validator=ValidatorModel(bool_exp='...', bool_exp_str='lambda value: (value.array[P_VALUE_POS] >= threshold)', thresholds=[], success='P-Value is greater or equal to 0.05', failure='P-Value is less than threshold 0.05', info=None, input_types=['mlte.evidence.types.array.Array'], creator_entity='validators', creator_function='p_value_greater_or_equal_to', creator_args=['0.05'])), TestCaseModel(identifier='ranksums channel loss G', goal='Check consistency between channel loss', qas_list=['card.default ...
