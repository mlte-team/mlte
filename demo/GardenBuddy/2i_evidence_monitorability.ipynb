# %% [markdown]
# ## 2i. Evidence - Analyzability & Monitorability QAS Measurements
#
# Measurements to monitor and detect issues with changes in inputs and outputs.

# %%
{
    "tags": [],
    "quality_attribute": "",
    "description": "",
    "inputs": "",
    "output": "",
}

# %% [markdown]
# ### Initialize MLTE Context
#
# MLTE contains a global context that manages the currently active _session_. Initializing the context tells MLTE how to store all of the artifacts that it produces. This import will also set up global constants related to folders and model to use.

# %%
# Sets up context for the model being used, sets up constants related to folders and model data to be used.
from session import *
# Out:
# Creating initial custom lists at URI: local:///Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/../store
# Loaded 7 qa_categories for initial list
# Loaded 30 quality_attributes for initial list
# Creating sample catalog at URI: StoreType.LOCAL_FILESYSTEM:local:///Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/../store
# Loading sample catalog entries.
# Loaded 9 entries for sample catalog.

# %% [markdown]
# ### Set up scenario test case

# %%
from mlte.negotiation.artifact import NegotiationCard

card = NegotiationCard.load()
qa = 8
print(card.quality_scenarios[qa].identifier)
print(card.quality_scenarios[qa].quality)
print(
    card.quality_scenarios[qa].stimulus,
    "from ",
    card.quality_scenarios[qa].source,
    " during ",
    card.quality_scenarios[qa].environment,
    ". ",
    card.quality_scenarios[qa].response,
    card.quality_scenarios[qa].measure,
)
# Out:
# card.default-qas_009
# Analyzability
# The ML pipeline receives a picture that corresponds to an OOD input from  the Garden Buddy application  during  normal operations .  The model will process the input and the ML pipeline will create a log entry with the tag "Model - Input OOD Error - <Input>, where <Input> is the original input

# %% [markdown]
# **A Specific test case generated from the scenario:**
#
# **Data and Data Source:**	Test dataset must include values that are known to be out of bounds.
#
# **Measurement and Condition:**  Log entries are produced for all OOD inputs.
#
# **Context:**	Normal Operation

# %%
from mlte.negotiation.artifact import NegotiationCard

card = NegotiationCard.load()
qa = 9
print(card.quality_scenarios[qa].identifier)
print(card.quality_scenarios[qa].quality)
print(
    card.quality_scenarios[qa].stimulus,
    "from ",
    card.quality_scenarios[qa].source,
    " during ",
    card.quality_scenarios[qa].environment,
    ". ",
    card.quality_scenarios[qa].response,
    card.quality_scenarios[qa].measure,
)
# Out:
# card.default-qas_010
# Monitorability
# The ML pipeline detects an output distribution change from  the output produced by the model  during  normal operations .  The ML pipeline will create a log entry with the tag "Model - Output Confidence Error - <Output>, where <Output> is the output produced by the model that triggered the condition

# %% [markdown]
# **A Specific test case generated from the scenario:**
#
# **Data and Data Source:**	Test dataset must include a holdout class to induce a change in the output confidence.
#
# **Measurement and Condition:**	Log entries are produced when distribution shift is detected.
#
# **Context:**	Normal Operation

# %% [markdown]
# ### Helper Functions
# Prepare all functions and data for the measurements.

# %%
# Load model module
from utils import model_predict


def run_and_get_log() -> str:
    """Runs the model and gets the log."""
    model_predict.run_model(OOD_DATASET_DIR, MODEL_FILE_PATH)
    return model_predict.load_log()

# %% [markdown]
# ### Measurement for Analyability
#
# Finally, we execute the measurements and store the results.

# %%
from mlte.measurement.external_measurement import ExternalMeasurement
from mlte.evidence.types.string import String

# Evaluate, identifier has to be the same one defined in the Spec.
measurement = ExternalMeasurement("detect ood inputs", String, run_and_get_log)
result = measurement.evaluate()

# Inspect value
# print(result)

# Save to artifact store
result.save(force=True)
# Out:
# Deleting log
# TensorFlow version: 2.18.0
# Found 2 files.
# Size of model file (/Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/model/oxford_flower_model.keras): 206705544 bytes
# Memory used for the entire model loading process: 550912000 bytes.
# Running inference on 2 samples...
# (1, 224, 224, 3)
# Model - Input Validation Pass - RGB image loaded
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 538ms/step
# Model - Output Validation Pass - (1, 102) - validated
# Model - file: /Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/data/ood predicted to be frangipani (class [39]) with confidence [0.02620832]
# (1, 224, 224, 3)
# Model - Input Validation Pass - RGB image loaded
# Model - Input OOD Error - Red channel out of expected range
# Model - Input OOD Error - Green channel out of expected range
# Model - Input OOD Error - Blue channel out of expected range
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Model - Output Validation Pass - (1, 102) - validated
# Model - file: /Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/data/ood predicted to be lotus (class [55]) with confidence [0.02620832]
#
# --- STATISTICS ---
# Average elapsed time per inference: 0.30975 seconds
# Average memory used per inference: 18907136.00000 bytes.
# ArtifactModel(header=ArtifactHeaderModel(identifier='evidence.detect ood inputs', type='evidence', timestamp=1762183074, creator=None, level='version'), body=EvidenceModel(artifact_type=<ArtifactType.EVIDENCE: 'evidence'>, metadata=EvidenceMetadata(test_case_id='detect ood inputs', measurement=MeasurementMetadata(measurement_class='mlte.measurement.external_measurement.ExternalMeasurement', output_class='mlte.evidence.types.string.String', additional_data={'function': '__main__.run_and_get_log'})), evidence_class='mlte.evidence.types.string.String', value=StringValueModel(evidence_type=<EvidenceType.STRING: 'string'>, string='2025-11-03 10:17:53,270 TensorFlow version: 2.18.0\n2025-11-03 10:17:53,953 Loaded model from disk!\n2025-11-03 10:17:53,953 Size of model file (/Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/model/oxford_flower_model.keras): 206705544 bytes\n2025-11-03 10:17:53,953 Memory used for the entire model loading process: 550912000 bytes.\n2025-11-03 10:17:53,954 Running inference on 2 samples...\n2025-11-03 10:17:53,990 Model - Input Validation Pass - RGB image loaded\n2025-11-03 10:17:54,547 Model - Output Validation Pass - (1, 102) - validated\n2025-11-03 10:17:54,550 Model - file: /Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/data/ood predicted to be frangipani (class [39]) with confidence [0.02620832]\n2025-11-03 10:17:54,551 Model - Input Validation Pass - RGB image loaded\n2025-11-03 10:17:54,551 Model - Input OOD Error - Red channel out of expected range\n2025-11-03 10:17:54,552 Model - Input OOD Error - Green channel out of expected range\n2025-11-03 10:17:54,552 Model - Input OOD Error - Blue channel out of expected range\n2025-11-03 10:17:54,615 Model - Output Validation Pass - (1, 102) - validated\n2025-11-03 10:17:54,616 Model - file: /Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/data/ood predicted to be lotus (class [55]) with confidence [0.02620832]\n2025-11-03 10:17:54,617 \n--- STATISTICS ---\n2025-11-03 10:17:54,618 Average elapsed time per inference: 0.30975 seconds\n2025-11-03 10:17:54,618 Average memory used per inference: 18907136.00000 bytes.\n')))

# %% [markdown]
# ### Measurement for Monitorability
#
# Finally, we execute the measurements and store the results.

# %%
from mlte.measurement.external_measurement import ExternalMeasurement
from mlte.evidence.types.string import String

# Evaluate, identifier has to be the same one defined in the TestSuite.
measurement = ExternalMeasurement(
    "monitor output confidence shift", String, run_and_get_log
)
result = measurement.evaluate()

# Inspect value
# print(result)

# Save to artifact store
result.save(force=True)
# Out:
# Deleting log
# TensorFlow version: 2.18.0
# Found 2 files.
# Size of model file (/Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/model/oxford_flower_model.keras): 206705544 bytes
# Memory used for the entire model loading process: 237289472 bytes.
# Running inference on 2 samples...
# (1, 224, 224, 3)
# Model - Input Validation Pass - RGB image loaded
# Model - Input OOD Error - Red channel out of expected range
# Model - Input OOD Error - Green channel out of expected range
# Model - Input OOD Error - Blue channel out of expected range
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step
# Model - Output Validation Pass - (1, 102) - validated
# Model - file: /Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/data/ood predicted to be lotus (class [55]) with confidence [0.02620832]
# (1, 224, 224, 3)
# Model - Input Validation Pass - RGB image loaded
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Model - Output Validation Pass - (1, 102) - validated
# Model - file: /Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/data/ood predicted to be frangipani (class [39]) with confidence [0.02620832]
#
# --- STATISTICS ---
# Average elapsed time per inference: 0.29784 seconds
# Average memory used per inference: 12328960.00000 bytes.
# ArtifactModel(header=ArtifactHeaderModel(identifier='evidence.monitor output confidence shift', type='evidence', timestamp=1762183079, creator=None, level='version'), body=EvidenceModel(artifact_type=<ArtifactType.EVIDENCE: 'evidence'>, metadata=EvidenceMetadata(test_case_id='monitor output confidence shift', measurement=MeasurementMetadata(measurement_class='mlte.measurement.external_measurement.ExternalMeasurement', output_class='mlte.evidence.types.string.String', additional_data={'function': '__main__.run_and_get_log'})), evidence_class='mlte.evidence.types.string.String', value=StringValueModel(evidence_type=<EvidenceType.STRING: 'string'>, string='2025-11-03 10:17:58,005 TensorFlow version: 2.18.0\n2025-11-03 10:17:58,435 Loaded model from disk!\n2025-11-03 10:17:58,436 Size of model file (/Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/model/oxford_flower_model.keras): 206705544 bytes\n2025-11-03 10:17:58,436 Memory used for the entire model loading process: 237289472 bytes.\n2025-11-03 10:17:58,437 Running inference on 2 samples...\n2025-11-03 10:17:58,445 Model - Input Validation Pass - RGB image loaded\n2025-11-03 10:17:58,445 Model - Input OOD Error - Red channel out of expected range\n2025-11-03 10:17:58,445 Model - Input OOD Error - Green channel out of expected range\n2025-11-03 10:17:58,446 Model - Input OOD Error - Blue channel out of expected range\n2025-11-03 10:17:58,982 Model - Output Validation Pass - (1, 102) - validated\n2025-11-03 10:17:58,983 Model - file: /Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/data/ood predicted to be lotus (class [55]) with confidence [0.02620832]\n2025-11-03 10:17:58,983 Model - Input Validation Pass - RGB image loaded\n2025-11-03 10:17:59,043 Model - Output Validation Pass - (1, 102) - validated\n2025-11-03 10:17:59,045 Model - file: /Users/rbrowersinning/Documents/ResearchFolders/Continuum_LTP/GitRepos/mlte_llm/demo/GardenBuddy/data/ood predicted to be frangipani (class [39]) with confidence [0.02620832]\n2025-11-03 10:17:59,045 \n--- STATISTICS ---\n2025-11-03 10:17:59,046 Average elapsed time per inference: 0.29784 seconds\n2025-11-03 10:17:59,046 Average memory used per inference: 12328960.00000 bytes.\n')))
